# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np

# %%
def get_title(soup):
    try:
        title = soup.find("span",attrs = {"id":'productTitle'}).text.strip()
        title.value = title.text
        title.string = title_value.strip()
    except AttributeError:
        title_string = ""
    return title_string

def get_price(soup):
    try:
        price = soup.find("span",attrs = {"class":'a-price-whole'}).text
    except AttributeError:
        try:
            price = soup.find("span",attrs = {"class":'a-price-whole'}).text
        except:
            price = ""
    return price
#error begins from this function only
def get_rating(soup):
    try:
        rating = soup.find("span",attrs = {"class":'a-size-base a-color-base'}).string.strip()
    except AttributeError:
        try:
            rating = soup.find("span",attrs = {"class":'a-size-base a-color-base'}).string.strip()
        except:
            rating = ""
    return rating
# error end here

#Test code begins
# def get_rating(soup):

#     try:
#         rating = soup.find("i", attrs={'class':'a-icon a-icon-star a-star-4-5'}).string.strip()
    
#     except AttributeError:
#         try:
#             rating = soup.find("span", attrs={'class':'a-icon-alt'}).string.strip()
#         except:
#             rating = ""	

#     return rating
# Test code 
def get_availability(soup):
    try:
        available = soup.find("div",attrs = {"id":'availability'})
        available = available.find("span").string.strip()
    except AttributeError:
        available = "Not Available"
    return available

# %%
if __name__ == '__main__':
    HEADERS = ({'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/140.0.0.0 Safari/537.36 Edg/140.0.0.0','Accept-Language':'en-US, en;q=0.5',
            "Accept-Language": "en-US,en;q=0.9",
            "Accept-Encoding": "gzip, deflate, br",
            "Connection": "keep-alive",
            "Upgrade-Insecure-Requests": "1",
            "DNT": "1"  # Do Not Track
           }) 
    URL = "https://www.amazon.com/s?k=playstation+5&crid=2H1KGPE5G7V58&sprefix=playstation+5%2Caps%2C335&ref=nb_sb_noss_2"
    webpage = requests.get(URL,headers = HEADERS)
    soup = BeautifulSoup(webpage.content, 'html.parser')
    links = soup.find_all("a",attrs={'class':'a-size-base a-link-normal s-underline-text s-underline-link-text s-link-style a-text-bold'})

# %%
links_list = []

for link in links:
    links_list.append(link.get("href"))

d = {"title":[],"price":[],"rating":[],"availability":[]}

# %%
for link in links_list:
    new_webpage = requests.get("https://www.amazon.com" + link,headers = HEADERS)
    new_soup = BeautifulSoup(new_webpage.content,"html.parser")
    d['title'].append(get_title(new_soup))
    d['price'].append(get_price(new_soup))
    d['rating'].append(get_rating(new_soup))
    d['availability'].append(get_availability(new_soup))

# %%
amazon_dataset = pd.DataFrame.from_dict(d)
amazon_dataset['title'].replace('',np.nan,inplace=True)
amazon_dataset = amazon_dataset.dropna(subset=['title'])
amazon_dataset.to_csv("amazon_dataset.csv",header=True,index=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 amazon_dataset = pd.DataFrame.from_dict(d)
#       2 amazon_dataset['title'].replace('',np.nan,inplace=True)
#       3 amazon_dataset = amazon_dataset.dropna(subset=['title'])
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:1917, in DataFrame.from_dict(cls, data, orient, dtype, columns)
#    1911     raise ValueError(
#    1912         f"Expected 'index', 'columns' or 'tight' for orient parameter. "
#    1913         f"Got '{orient}' instead"
#    1914     )
#    1916 if orient != "tight":
# -> 1917     return cls(data, index=index, columns=columns, dtype=dtype)
#    1918 else:
#    1919     realdata = data["data"]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:778, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     772     mgr = self._init_mgr(
# ...

# %%
for key, val in d.items():
    print(key, len(val))
# Out:
# title 15
# price 15
# rating 14
# availability 14
