# %%
# Mini project - Data Engineer

# %%
print("Let's begin the game :) ")
# Out:
# Let's begin the game :)

# %%
# !pip install bs4

# %%
# !pip install requests

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
URL = "https://www.amazon.com/s?k=playstation+5&crid=2H1KGPE5G7V58&sprefix=playstation+5%2Caps%2C335&ref=nb_sb_noss_2"

# %%
# URL = "https://www.amazon.in/s?k=playstation+5&crid=2H1KGPE5G7V58&sprefix=playstation+5%2Caps%2C335&ref=nb_sb_noss_2"

# %%
HEADERS = ({'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/140.0.0.0 Safari/537.36 Edg/140.0.0.0','Accept-Language':'en-US, en;q=0.5',
            "Accept-Language": "en-US,en;q=0.9",
            "Accept-Encoding": "gzip, deflate, br",
            "Connection": "keep-alive",
            "Upgrade-Insecure-Requests": "1",
            "DNT": "1"  # Do Not Track
           }) 
# real one

# %%
# HEADERS = ({'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/118.0.5993.90 Safari/537.36 Edg/118.0.2088.46','Accept-Language':'en-US, en;q=0.5'})

# %%
webpage = requests.get(URL,headers = HEADERS)

# %%
webpage
# Out:
# <Response [200]>

# %%
type(webpage.content)
# Out:
# bytes

# %%
soup = BeautifulSoup(webpage.content, 'html.parser')

# %%
# soup

# %%
links = soup.find_all("a",attrs={'class':'a-size-base a-link-normal s-underline-text s-underline-link-text s-link-style a-text-bold'})

# %%
# a-link-normal s-line-clamp-2 s-line-clamp-3-for-col-12 s-link-style a-text-normal
# links = soup.find_all("a",attrs={'class':'a-size-base a-link-normal s-underline-text s-underline-link-text s-link-style a-text-bold'})

# %%
# links

# %%
links[0]
# Out:
# <a class="a-size-base a-link-normal s-underline-text s-underline-link-text s-link-style a-text-bold" href="/PlayStation%C2%AE5-console-slim-PlayStation-5/dp/B0CL61F39H/ref=sr_1_1?crid=2H1KGPE5G7V58&amp;dib=eyJ2IjoiMSJ9.iljGzJ9gK4edCvZ4knhV5nMRxPc_oFRpYjPaBK44XhyiSI8Z7q0mqPtSmKdme6aal0ZumjQrH4ZYepNAnsf9p7JI3htLw8mq9w8U-MDZWh2affJB0KFcC6pnmRlH0JiXFLMapph06IPGco424yLn7GNgFHISa8OVbkEq8JyV_vfZ9SlxI1YQ9BfbH6e7HDcJ5s_O6glreRn_LTfdwT0swa0VwlyYHlsR8ET7pVSDgHQ.kiYW6R0d0CaN4-pFvPcABC48IQD06GzL6y-CEKZYM5s&amp;dib_tag=se&amp;keywords=playstation+5&amp;qid=1759403804&amp;sprefix=playstation+5%2Caps%2C335&amp;sr=8-1">PlayStation 5</a>

# %%
link = links[0].get('href')

# %%
link
# Out:
# '/PlayStation%C2%AE5-console-slim-PlayStation-5/dp/B0CL61F39H/ref=sr_1_1?crid=2H1KGPE5G7V58&dib=eyJ2IjoiMSJ9.iljGzJ9gK4edCvZ4knhV5nMRxPc_oFRpYjPaBK44XhyiSI8Z7q0mqPtSmKdme6aal0ZumjQrH4ZYepNAnsf9p7JI3htLw8mq9w8U-MDZWh2affJB0KFcC6pnmRlH0JiXFLMapph06IPGco424yLn7GNgFHISa8OVbkEq8JyV_vfZ9SlxI1YQ9BfbH6e7HDcJ5s_O6glreRn_LTfdwT0swa0VwlyYHlsR8ET7pVSDgHQ.kiYW6R0d0CaN4-pFvPcABC48IQD06GzL6y-CEKZYM5s&dib_tag=se&keywords=playstation+5&qid=1759403804&sprefix=playstation+5%2Caps%2C335&sr=8-1'

# %%
product_list = "https://www.amazon.com" + link

# %%
product_list
# Out:
# 'https://www.amazon.com/PlayStation%C2%AE5-console-slim-PlayStation-5/dp/B0CL61F39H/ref=sr_1_1?crid=2H1KGPE5G7V58&dib=eyJ2IjoiMSJ9.iljGzJ9gK4edCvZ4knhV5nMRxPc_oFRpYjPaBK44XhyiSI8Z7q0mqPtSmKdme6aal0ZumjQrH4ZYepNAnsf9p7JI3htLw8mq9w8U-MDZWh2affJB0KFcC6pnmRlH0JiXFLMapph06IPGco424yLn7GNgFHISa8OVbkEq8JyV_vfZ9SlxI1YQ9BfbH6e7HDcJ5s_O6glreRn_LTfdwT0swa0VwlyYHlsR8ET7pVSDgHQ.kiYW6R0d0CaN4-pFvPcABC48IQD06GzL6y-CEKZYM5s&dib_tag=se&keywords=playstation+5&qid=1759403804&sprefix=playstation+5%2Caps%2C335&sr=8-1'

# %%
new_webpage = requests.get(product_list,headers = HEADERS)

# %%
new_webpage
# Out:
# <Response [200]>

# %%
new_soup = BeautifulSoup(new_webpage.content, 'html.parser')

# %%
# new_soup

# %%
new_soup.find("span",attrs = {"id":'productTitle'}).text.strip()
# Out:
# 'PlayStation®5 console (slim)'

# %%
new_soup.find("span",attrs = {"class":'a-price-whole'}).text
# Out:
# '6,335.'

# %%
new_soup.find("span",attrs = {"class":'a-size-base a-color-base'}).text.strip()
# Out:
# '4.7'
